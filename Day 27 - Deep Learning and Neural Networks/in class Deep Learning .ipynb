# %%
# 2.1 Simple neuron example in code

import numpy as np

def neuron_output(x1, x2, w1, w2, b):
    """
    A simple neuron:
    z = w1*x1 + w2*x2 + b
    Here we will NOT apply an activation yet, just return z.
    """
    z = w1 * x1 + w2 * x2 + b
    return z

# Example inputs (e.g., hours studied, extra classes attended)
x1 = 5   # feature 1
x2 = 2   # feature 2

# Example weights and bias
w1 = 0.8
w2 = 1.2
b = -1.0

z = neuron_output(x1, x2, w1, w2, b)
print("Linear combination (z):", z)
# Out:
# Linear combination (z): 5.4

# %% [markdown]
# - Pass the output through a step function
# - Print a decision based on the output
#
# Step function:
# - if the input is less than or equal to zero, output = 0
# - otherwise output = 1

# %%
def activation(z):
    if z > 0:
        return 1
    return 0


y = activation(0)


def outputs(y):
    if y == 0:
        print('Noops! We nat goin yanywhereeeeee')
    else:
        print('Yaaaaaaay! Lessss GOOOOOOOO!!!!')

# %%
outputs(activation(neuron_output(x1, x2, w1, w2, b)))
# Out:
# Yaaaaaaay! Lessss GOOOOOOOO!!!!

# %%
def activation(z):
    if z > 0:
        return 1
    return 0


y = activation(0)

# %%
y = activation([3,3,4,5,5,])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 y = activation([3,3,4,5,5,])
#
# Cell In[11], line 2, in activation(z)
#       1 def activation(z):
# ----> 2     if z > 0:
#       3         return 1
#       4     return 0
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
data = [[2,3,4,5],
        [2,3,4,5],
        [2,3,4,5],
        [2,3,4,5],
        [2,3,4,5]
]

def image(data):
    
    if z > 0:
        return 1
    return 0

# %%
data = [[25,30000,30,5],
        [45,53000,53,5],
        [19,73000,73,5],
        [18,43000,43,5],
        [20,25000,25,5]
]

data = [[25,30000,4,5],
        [45,53000,4,5],
        [19,73000,4,5],
        [18,43000,4,5],
        [20,25000,4,5]
]

x1 = [ ages ]
x2 = [salaries]

E x1 * 0.9  = 230

E x2 * 0.1 = 23000
