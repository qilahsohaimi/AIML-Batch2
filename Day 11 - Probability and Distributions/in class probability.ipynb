# %% [markdown]
# ### Probability
#
# - Likelihood of something
# - chances of something to happen
#
# - Why on earth do we need to study probability in an AI ML Class?
#
#     - for machine learning - because machine will be predicting - for future
#     - Helps you forcast something based on the data
#
#     - ML - machine to give outputs (any kind of machine). YES or NO
#     - Not just output.
#     - Decision - confidence
#     - machine calculated the possiblity of an answer
#
#      - we do not just use if and else:
#
#      - ML models calculate possiblities
#      - how they calculate these. Probability and distribution
#     -

# %% [markdown]
# - One simple example:
#  - Cats and dogs example for AI ML
